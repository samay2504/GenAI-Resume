# %% [markdown]
# Environment Setup

# %%
# !pip3 install transformers datasets torch scikit-learn pandas
# Out:
# Requirement already satisfied: transformers in d:\lusak.tech\.venv\lib\site-packages (4.47.1)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch in d:\lusak.tech\.venv\lib\site-packages (2.5.1)
# Requirement already satisfied: scikit-learn in d:\lusak.tech\.venv\lib\site-packages (1.6.0)
# Requirement already satisfied: pandas in d:\lusak.tech\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: filelock in d:\lusak.tech\.venv\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\lusak.tech\.venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in d:\lusak.tech\.venv\lib\site-packages (from transformers) (4.67.1)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in d:\lusak.tech\.venv\lib\site-packages (from datasets) (3.11.11)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\lusak.tech\.venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in d:\lusak.tech\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in d:\lusak.tech\.venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in d:\lusak.tech\.venv\lib\site-packages (from torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in d:\lusak.tech\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\lusak.tech\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: scipy>=1.6.0 in d:\lusak.tech\.venv\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\lusak.tech\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\lusak.tech\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\lusak.tech\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\lusak.tech\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\lusak.tech\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\lusak.tech\.venv\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in d:\lusak.tech\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\lusak.tech\.venv\lib\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\lusak.tech\.venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\lusak.tech\.venv\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\lusak.tech\.venv\lib\site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: colorama in d:\lusak.tech\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\lusak.tech\.venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pyarrow-18.1.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Using cached xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Installing collected packages: xxhash, pyarrow, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 pyarrow-18.1.0 xxhash-3.5.0

# %% [markdown]
# Code for Fine-Tuning DistilBERT

# %%
import os
import torch
from torch.utils.data import DataLoader
from transformers import DistilBertForSequenceClassification, AdamW, AutoTokenizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
import pandas as pd

# Load dataset
csv_path = "D:/Lusak.tech/combined_resumes.csv"  # Replace with a relative path if needed
if not os.path.exists(csv_path):
    raise FileNotFoundError(f"Dataset file not found at: {csv_path}")

df = pd.read_csv(csv_path)

# Ensure dataset contains required columns
if "text" not in df.columns or "label" not in df.columns:
    raise ValueError("The dataset must contain 'text' and 'label' columns.")

# Tokenize the data
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['text'], df['label'], test_size=0.2, stratify=df['label'], random_state=42
)

train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, max_length=128)
val_encodings = tokenizer(list(val_texts), truncation=True, padding=True, max_length=128)

# Prepare datasets for PyTorch
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'input_ids': torch.tensor(self.encodings['input_ids'][idx]),
            'attention_mask': torch.tensor(self.encodings['attention_mask'][idx]),
            'labels': torch.tensor(self.labels[idx])
        }

train_dataset = CustomDataset(train_encodings, train_labels.tolist())
val_dataset = CustomDataset(val_encodings, val_labels.tolist())

# Load pre-trained DistilBERT model
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=len(df['label'].unique())
)
model.to(device)

# Use weighted loss to handle class imbalance
class_weights = torch.tensor(
    [len(df) / (df['label'].value_counts()[i] * 2) for i in sorted(df['label'].unique())],
    dtype=torch.float
).to(device)
loss_fn = torch.nn.CrossEntropyLoss(weight=class_weights)

# Define optimizer and dataloaders
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# Train the model for fine-tuning
epochs = 3
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in train_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        optimizer.zero_grad()
        outputs = model(**batch)
        loss = outputs.loss  # Use the model's built-in loss for classification tasks
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch + 1}: Train Loss = {total_loss / len(train_loader)}")

    # Validation
    model.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch in val_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = model(**batch)
            val_loss += outputs.loss.item()
            predictions = torch.argmax(outputs.logits, dim=1)
            correct += (predictions == batch['labels']).sum().item()
            total += batch['labels'].size(0)

    print(f"Validation Accuracy = {correct / total * 100:.2f}%, Validation Loss = {val_loss / len(val_loader):.4f}")


    # Validation phase
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in val_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = model(**batch)
            predictions = torch.argmax(outputs.logits, dim=1)
            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(batch['labels'].cpu().numpy())

    f1 = f1_score(all_labels, all_preds, average="weighted", zero_division=1)
    print(f"Validation F1-Score = {f1:.2f}")

# Save the trained model and tokenizer
model.save_pretrained("./fine_tuned_distilbert")
tokenizer.save_pretrained("./fine_tuned_distilbert")

# Classification report
print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=["Human-written", "AI-generated"], zero_division=1))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1: Train Loss = 0.22096836803531325
# Validation Accuracy = 100.00%, Validation Loss = 0.0556
# Validation F1-Score = 1.00
# Epoch 2: Train Loss = 0.030748086364788783
# Validation Accuracy = 100.00%, Validation Loss = 0.0099
# Validation F1-Score = 1.00
# Epoch 3: Train Loss = 0.00847085122950375
# Validation Accuracy = 100.00%, Validation Loss = 0.0040
# Validation F1-Score = 1.00
# Classification Report:
#                precision    recall  f1-score   support
#
# Human-written       1.00      1.00      1.00         5
#  AI-generated       1.00      1.00      1.00        68
#
#      accuracy                           1.00        73
#     macro avg       1.00      1.00      1.00        73
#  weighted avg       1.00      1.00      1.00        73

# %% [markdown]
# Testing

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
import torch
import json
import chardet

# Function to detect file encoding using chardet
def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

# Load model and tokenizer
model = DistilBertForSequenceClassification.from_pretrained("./fine_tuned_distilbert")
tokenizer = DistilBertTokenizer.from_pretrained("./fine_tuned_distilbert")

# Function to predict AI or human-written resume
def detect_resume_type(resume_text):
    inputs = tokenizer(resume_text, return_tensors="pt", truncation=True, padding="max_length", max_length=512)
    outputs = model(**inputs)
    prediction = torch.argmax(outputs.logits).item()
    return "AI-generated" if prediction == 1 else "Human-written"

# Recursive function to extract text from JSON
def extract_text_from_json(data, text=""):
    if isinstance(data, dict):
        for key, value in data.items():
            text = extract_text_from_json(value, text)
    elif isinstance(data, list):
        for item in data:
            text = extract_text_from_json(item, text)
    elif isinstance(data, (str, int, float)):
        text += str(data) + "\n"
    return text

# Function to load resumes from a .json file and detect type
def detect_from_json(file_path):
    # Detect encoding of the file
    file_encoding = detect_encoding(file_path)
    print(f"The detected encoding of the JSON file is: {file_encoding}")

    # Open the file with the detected encoding
    with open(file_path, 'r', encoding=file_encoding) as f:
        data = json.load(f)

    # Extract all text from JSON
    resume_text = extract_text_from_json(data)

    # Detect the type of resume
    result = detect_resume_type(resume_text)
    print(f"Resume Type: {result}")

# Example usage
json_file_path = "D:/Lusak.tech/Dataset/Mehar.json"  # Replace with your .json file path
detect_from_json(json_file_path)
# Out:
# The detected encoding of the JSON file is: utf-8
# Resume Type: Human-written

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
import torch
import json
import os
import chardet

# Function to detect file encoding using chardet
def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

# Load model and tokenizer
model = DistilBertForSequenceClassification.from_pretrained("./fine_tuned_distilbert")
tokenizer = DistilBertTokenizer.from_pretrained("./fine_tuned_distilbert")

# Function to predict resume type
def detect_resume_type(resume_text):
    inputs = tokenizer(resume_text, return_tensors="pt", truncation=True, padding="max_length", max_length=512)
    outputs = model(**inputs)
    prediction = torch.argmax(outputs.logits).item()

    # Map prediction to label
    labels = {0: "Human-written", 1: "AI-generated", 2: "Faulty"}
    return labels.get(prediction, "Unknown")

# Recursive function to extract text from JSON
def extract_text_from_json(data, text=""):
    if isinstance(data, dict):
        for key, value in data.items():
            text = extract_text_from_json(value, text)
    elif isinstance(data, list):
        for item in data:
            text = extract_text_from_json(item, text)
    elif isinstance(data, (str, int, float)):
        text += str(data) + "\n"
    return text

# Function to process a single resume file
def process_resume(file_path):
    try:
        # Detect encoding of the file
        file_encoding = detect_encoding(file_path)
        print(f"Detected encoding for {file_path}: {file_encoding}")

        # Open and parse the JSON file
        with open(file_path, 'r', encoding=file_encoding) as f:
            data = json.load(f)

        # Extract all text from JSON
        resume_text = extract_text_from_json(data)

        # Detect the type of resume
        result = detect_resume_type(resume_text)
        return {"file_path": file_path, "result": result}
    except Exception as e:
        return {"file_path": file_path, "error": str(e)}

# Function to process multiple resumes in a directory
def process_resumes_in_directory(directory_path, output_file="results.json"):
    results = []

    for file_name in os.listdir(directory_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(directory_path, file_name)
            result = process_resume(file_path)
            results.append(result)

    # Save results to output file
    with open(output_file, 'w', encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=4)

    print(f"Results saved to {output_file}")

# Example usage
directory_path = "D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes"  # Replace with your directory containing JSON files
process_resumes_in_directory(directory_path)
# Out:
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aaron-visser.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\abel.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\abhishek-clark.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\abraham-mokhtari.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\abram-c.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\adina-melchor.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aditya-soni.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\adrian-singh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aimee-harp.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aimee-jaffee.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ak-lam.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alaina-bogdan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alaina-lail.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alberto-monge.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aleena-abdul-thomas.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alex-vazquez.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alexander-figueroa.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aline-hwang.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aline-mitov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\allan-parkes.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alleen-neace.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\almeda-enyeart.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\alvaro-singer.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\amar-lyon.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\andrea-battaglia.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\andrea-gutierrez.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\angelique-wunder.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\anitra-abbate.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ara-jaffee.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\arjun-spinelli.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\armanda-cloutier.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\arnar-dobrev.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\arvydas-nandra.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\aurore-donat.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\avarjana-romaniv.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ayush-singh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\bart.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\belshaw-krutewicz.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ben-rodriguez-ortiz.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\benjamin-segall.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\bernice-earl.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\bettyann-dunnigan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\billy-lanzafame.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\bobby-toor.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\brad-kanoufi.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\brandon-oyemade.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\breann-gary.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\brenton-eckhoff.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\brian-d-reynolds.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\brin-coordsen.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cai-fei-fei.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\calandra-osuna.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\camelia-luk.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cameron-alagaratnam.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\candidate-herbst.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\carmon-styron.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\casey-name-mureriwa.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cassaundra-amann.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\chad-lancheros.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\charis-covelli.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\charlotte-jahanbakhsh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cherri-barak.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\chetan-robey.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\chia-lail.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\chris-kerckhove.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\christon-anshul-abdul.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\chrystal-chaloux.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\claudie-medders.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cole-schleutker.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\concetta-chartrand.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\conrad.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\corrina-spruill.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\cristian-turkin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dan-glendenning.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\danelle-whittemore.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\danuta-teague.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dariusz-paruthi.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\david-adams.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\david-bernhard.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\david-soto.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\davide-minh-aguila-sims.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\daxter-ryan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\deanne-cortina.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\deepika-gunda.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\deidra-mcmullan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\delon-mcfly.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\derek-berlin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dhwanil-fabro.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dierdre-vannostrand.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dinesh-el-mclaughlin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dmitri-milos.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\donna-kossman.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dorothy-ellwood.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dovie-pabst.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dragan-waltz.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dragan-wu.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\drew-seif.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dusan-elias-autar-weerapurage.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\dustin-dhruva.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\eddy-nixon.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\eduardo-chinnakonda-shehan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\elena-toor.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\elenore-glasper.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\elijah-hildreth.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\elinor-meunier.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\eliz-yokum.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ellwood.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\erik-rosemberg.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\erik-thorselius.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\esther-kumar-ferreira-perez-v.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ethan-simmons.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\fabian-mittal.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\fang-haniquaut.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\felice-villasenor.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\felipe-shah.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\filiberto-redinger.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\fran-flinchbaugh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\francesco-donato.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\fredda-foulk.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\gabriel-mahmood.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\genia-hout.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\genna-sargeant.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\geofrey-shirhatti.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\giacomelli.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\goncalves.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\greta-griffeth.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\guan-simon.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\guido-koch.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\guilherme-jeff-k.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\gustavo-jonusonis.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ha-redmond.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\halley-salvia.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\hank-jay-torre-mureriwa-wang-lee.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\harry-cristina.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\herve-vermande.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\hien-filip-mclaughlin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\hilal-filimonov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\hilary-carasco.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\iesha-hernandes.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\itay-konig.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ivan-maciver.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\j-johnson.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ja-charlton.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jacob-narayanan.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jake-gaba.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jakub-heagney.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\james-j-newberry.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jared-dutta.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jarvela.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jason-basanese.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jason-kholodnov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\javier-fabro.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jayne-lion.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeanine-avent.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeannetta-masuda.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeffrey-a-pullman.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeffrey-anderson.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeffrey-riedemann.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jentan-bruno.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jeremy-briones.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jesse-le.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joe.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joel-macey.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joel-revard.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\john-d-nagengast.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\john-hamson.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\john-meyers.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\john-tenezaca.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\jose-nikolay-da-ramos.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\josh-ailin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\josh-schrader.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joshua-sagar-poffenberger.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joshua-shlemmer.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\joshua-simmons.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\julian-lawley.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\julianna-yokum.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\julieta-cress.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\juno-lundgren.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\justin-cantu.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kanoufi.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\katherina-markert.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kathrine-lovejoy.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\keila-cordova.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kemal-olivares.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ken-corbett.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kenyetta-algarin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\khalilah-littleton.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\konstantin-dhar.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\korrawit-jahanbakhsh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kristi-karsten.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\krzysztof-seelig.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kum-pontes.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\kurt-owerczuk.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lakeshia-overton.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lavenia-lookabaugh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lavi-koval.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\leatrice-belding.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lex-malta.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\liliana-schanz.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\linh-nguyen.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\loretta-belmont.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lorrine-sotomayor.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lourie-lindemann.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lucas-vazquez.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\lucrecia-petrey.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\luis-fernando-kishore-martinez.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\luisa-crossno.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\luke-nayak.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\madalyn-swartwood.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\madonna-lieber.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\madonna-scheurer.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mallory-sillman.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\malone.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mandi-schechter.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\manuel-rim.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\marek-yilmaz.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\margart-nicoletti.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\marina-suraj-oskarsson-nikam.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mariusz-mikeska.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\marry-morillo.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mary-fournier.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\maryam-telford.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\maryanne-hoyle.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mason-nero.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\matas-ye.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mathieu-benning.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mathieu-traube.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\matjah-santos-jonusonis-buja.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\matt-landry.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\maxime-ivanov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mckenzie-halpern.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mehran-koesnadi.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\meredith-antley.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\michael-acreman.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\michal-talaga.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\michelina-battiste.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\micki-ruby.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mike-al-r-de-gomez.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\milos-pratama.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\miroslav-parker.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\mohamad-kadenbach.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\molly-zadeh.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nadun-lassaletta.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nate-zaplaic.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nathan-macinnes.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\natividad-hessler.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nayib-caglin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nayib-snuggle.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\neal-carpino.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\neil-paddock.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nguyen-valing.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nicholas-boutboul.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nick-turner.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nicolas-zhbankov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\nishanth-jeakins.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\no.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\opal-mcmillian.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\orlando-wada.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\oskar-jensen.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\owen-dumit.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\pablo-acuna.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\pablo-ho.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\pandora-beahm.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\patil.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\paul-sangeet-urrutia-kurland.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\phil.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\philip-aleksandrov.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\quincy-verne.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\rachele-royster.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ravi-van.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\redinger.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\resume.json: utf-8
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\robert-page-valencia.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\robt-alpers.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\rodrigo-matheus.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\romaniv-mussorin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\rosalba-fluharty.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\ryan-ferreira-gray.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\sabina-urso.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\sacha-jay.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\sachin-kumar.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\samuel-casas.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\samuel-mosteller.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\sanna-raqueebuddin.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\scott-tolksdorf.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\shantel-tindell.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\shaun-radvilavicius.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\shayna-lingerfelt.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\shrinithi-kumar.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\silvan-bogush.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\siridet-ofonime.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\soon-epling.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\srdjan-sannerstedt.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\srikanth-mittapally.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\stanford-sills.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\stefani-carwile.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\suho-antonio-jain.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\susanne-agular.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\susy-staller.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\sylvain-jayappa.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\temeka-dwight.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tereasa-huckaby.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tester-wang.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\thi-sammet.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\toby-mcglynn.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tom-o.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tonette-london.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\trista-mercure.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tristan-satalkar.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\trung.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\tyler-peters.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\valentin-le-oliveira.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\valentin-le.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\valrie-geesey.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\varun-lymber.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\verena-stanhope.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\vernita-sim.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\vikhyath-shukla.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\vishal-riedemann.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\viviana-sledge.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\vyas.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\waldo-gillingham.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\wendi-bourbon.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\what.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\william-bailey.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\wilson-duc-el-duy.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\wolden-moiseenko.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\wyatt-tandon.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\xiomara-hardt.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yajan-kim.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yeltsin-kc.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yevhenii-gurbiel.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yolonda-cassella.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yun-c-hai-sevigny-richard.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yun-lahlali.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\yuri-k-peterson.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\zalewski-thet-naranjo.json: ascii
# Detected encoding for D:/Lusak.tech/jsonresume-fake-master/jsonresume-fake-master/resumes\zane-simon.json: ascii
# Results saved to results.json
